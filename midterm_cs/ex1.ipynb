# %%
import pandas as pd
import numpy as np
import datetime

# %%
x = [1,2,4,2,1,34, "ciao bella pt2"]

xstr = str(x)

print(xstr)

today = datetime.datetime.now().strftime('%w')


print(today)
# Out:
# [1, 2, 4, 2, 1, 34, 'ciao bella pt2']
# 3
