# %%
from IPython.display import Markdown, Image, display

md_path = "/Users/jacopomichelacci/FINM_32500/assignment_2/report/markdown_report.md"
png_path = "/Users/jacopomichelacci/FINM_32500/assignment_2/report/equity.png"

# %% [markdown]
# ## RUN SCRIPT TO REFRESH

# %%
# Display the Markdown report (formatted table + text)
with open(md_path, "r") as f:
    md_content = f.read()


display(Markdown(md_content))

# Display the equity curve image below
display(Image(filename=png_path))
# Out:
# #Strategy Performance Report
#
# | Strategy                | Total Return |   Sharpe  | Max Drawdown | # Trades |
# |-------------------------|--------------|-----------|--------------|----------:|
# | BenchmarkStrat            |      9.45% |    -2.12 |     -2.04% |     501 |
# | MACDStrategy              |   1686.74% |     0.64 |    -53.72% |   17739 |
# | MovingAverageCrossover    |    582.78% |     0.58 |    -40.87% |   13382 |
# | RSIStrategy               |    586.86% |     0.58 |    -40.58% |   13408 |
# | VolatilityBreakout        |   2492.00% |     0.63 |    -67.69% |   18077 |
